# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import matplotlib.colors as colors
import pandas as pd

# circ = Circle(x,y, 0.5, color=)

# %%
# Generate data...
t = np.linspace(0, 2 * np.pi, 20)
x = np.sin(t)
y = np.cos(t)

plt.rcParams['image.cmap'] = 'jet'
plt.scatter(t,x,c=y, s=100)
# for i in range(0,len(t)): 
#   circ = plt.Circle((i,x[i]), 0.5, color='g')
  #print(i, t[i], x[i], y[i],)
plt.show()
